# %%
import mmparser_test
parser = mmparser_test.MarkdownParser()
parser.parseFile('test_document.md')
parser.exportHTML('test_document.html')
# Out:
# reading file...
# parsing line: 0, previous line type: Blank
# creating an object : header
# parsing line: 1, previous line type: Blank
# parsing line: 2, previous line type: Blank
# parsing line: 3, previous line type: Normal
# parsing line: 4, previous line type: Blank
# creating an object : header
# parsing line: 5, previous line type: Blank
# parsing line: 6, previous line type: Normal
# creating an object : Inline object
# parsing line: 7, previous line type: Blank
# creating an object : Tagged block
# parsing line: 8, previous line type: Blank
# parsing line: 9, previous line type: Blank
# creating an object : header
# parsing line: 10, previous line type: Blank
# parsing line: 11, previous line type: Normal
# parsing line: 12, previous line type: Normal
# parsing line: 13, previous line type: Normal
# parsing line: 14, previous line type: Blank
# creating an object : header
# parsing line: 15, previous line type: Blank
# parsing line: 16, previous line type: Normal
# creating an object : Inline object
# parsing line: 17, previous line type: Blank
# creating an object : header
# parsing line: 18, previous line type: Blank
# parsing line: 19, previous line type: Normal
# parsing line: 20, previous line type: Normal
# parsing line: 21, previous line type: Blank
# parsing line: 22, previous line type: Normal
# parsing line: 23, previous line type: Blank
# creating an object : header
# parsing line: 24, previous line type: Blank
# parsing line: 25, previous line type: Normal
# creating an object : header
# parsing line: 26, previous line type: Blank
# parsing line: 27, previous line type: Normal
# creating an object : header
# parsing line: 28, previous line type: Blank
# parsing line: 29, previous line type: Blank
# creating an object : header
# parsing line: 30, previous line type: Blank
# creating an object : header
# parsing line: 31, previous line type: Blank
# creating an object : header
# parsing line: 32, previous line type: Blank
# creating an object : header
# parsing line: 33, previous line type: Blank
# creating an object : header
# parsing line: 34, previous line type: Blank
# creating an object : header
# parsing line: 35, previous line type: Blank
# parsing line: 36, previous line type: Blank
# creating an object : header
# parsing line: 37, previous line type: Blank
# parsing line: 38, previous line type: BlockQuote
# parsing line: 39, previous line type: BlockQuote
# parsing line: 40, previous line type: BlockQuote
# parsing line: 41, previous line type: BlockQuote
# creating an object : block quote
# parsing line: 0, previous line type: Blank
# parsing line: 1, previous line type: Normal
# parsing line: 2, previous line type: Blank
# parsing line: 3, previous line type: Normal
# parsing line: 4, previous line type: Normal
# parsing line: 42, previous line type: Blank
# parsing line: 43, previous line type: BlockQuote
# parsing line: 44, previous line type: BlockQuote
# creating an object : block quote
# parsing line: 0, previous line type: Blank
# parsing line: 1, previous line type: Normal
# parsing line: 2, previous line type: Normal
# parsing line: 45, previous line type: Blank
# parsing line: 46, previous line type: BlockQuote
# parsing line: 47, previous line type: BlockQuote
# parsing line: 48, previous line type: BlockQuote
# parsing line: 49, previous line type: BlockQuote
# parsing line: 50, previous line type: BlockQuote
# creating an object : block quote
# parsing line: 0, previous line type: Blank
# parsing line: 1, previous line type: Normal
# parsing line: 2, previous line type: Blank
# parsing line: 3, previous line type: BlockQuote
# creating an object : block quote
# parsing line: 0, previous line type: Blank
# parsing line: 1, previous line type: Normal
# parsing line: 4, previous line type: Blank
# parsing line: 5, previous line type: Normal
# parsing line: 51, previous line type: Blank
# parsing line: 52, previous line type: BlockQuote
# parsing line: 53, previous line type: BlockQuote
# parsing line: 54, previous line type: BlockQuote
# parsing line: 55, previous line type: BlockQuote
# parsing line: 56, previous line type: BlockQuote
# parsing line: 57, previous line type: BlockQuote
# parsing line: 58, previous line type: BlockQuote
# parsing line: 59, previous line type: BlockQuote
# creating an object : block quote
# parsing line: 0, previous line type: Blank
# creating an object : header
# parsing line: 1, previous line type: Blank
# parsing line: 2, previous line type: Blank
# parsing line: 3, previous line type: olLists
# parsing line: 4, previous line type: olLists
# parsing line: 5, previous line type: olLists
# creating an object : ol lists
# creating an object : list item
# parsing line: 0, previous line type: Blank
# parsing line: 1, previous line type: Normal
# parsing line: 2, previous line type: Normal
# parsing line: 5, previous line type: Blank
# parsing line: 6, previous line type: Normal
# parsing line: 7, previous line type: Blank
# parsing line: 8, previous line type: CodeBlock
# creating an object : code block
# parsing line: 60, previous line type: Blank
# creating an object : header
# parsing line: 61, previous line type: Blank
# parsing line: 62, previous line type: ulLists
# parsing line: 63, previous line type: ulLists
# parsing line: 64, previous line type: ulLists
# parsing line: 65, previous line type: ulLists
# parsing line: 66, previous line type: ulLists
# parsing line: 67, previous line type: ulLists
# parsing line: 68, previous line type: ulLists
# parsing line: 69, previous line type: ulLists
# parsing line: 70, previous line type: ulLists
# parsing line: 71, previous line type: ulLists
# parsing line: 72, previous line type: ulLists
# parsing line: 73, previous line type: ulLists
# parsing line: 74, previous line type: ulLists
# parsing line: 75, previous line type: ulLists
# parsing line: 76, previous line type: ulLists
# creating an object : ul lists
# creating an object : list item
# parsing line: 0, previous line type: Blank
# parsing line: 1, previous line type: Normal
# parsing line: 2, previous line type: Normal
# parsing line: 3, previous line type: Normal
# parsing line: 4, previous line type: Blank
# creating an object : list item
# parsing line: 0, previous line type: Blank
# parsing line: 1, previous line type: ulLists
# parsing line: 2, previous line type: ulLists
# parsing line: 3, previous line type: ulLists
# creating an object : ul lists
# creating an object : list item
# parsing line: 0, previous line type: Blank
# creating an object : list item
# parsing line: 0, previous line type: Blank
# creating an object : ul lists
# creating an object : list item
# parsing line: 0, previous line type: Blank
# creating an object : list item
# parsing line: 0, previous line type: Blank
# creating an object : list item
# parsing line: 0, previous line type: Blank
# creating an object : ul lists
# creating an object : list item
# parsing line: 0, previous line type: Blank
# creating an object : list item
# parsing line: 0, previous line type: Blank
# creating an object : list item
# parsing line: 0, previous line type: Blank
# parsing line: 1, previous line type: ulLists
# parsing line: 2, previous line type: ulLists
# parsing line: 3, previous line type: ulLists
# parsing line: 4, previous line type: ulLists
# creating an object : ul lists
# creating an object : list item
# parsing line: 0, previous line type: Blank
# parsing line: 1, previous line type: Normal
# creating an object : list item
# parsing line: 0, previous line type: Blank
# parsing line: 1, previous line type: ulLists
# parsing line: 2, previous line type: ulLists
# creating an object : ul lists
# creating an object : list item
# parsing line: 0, previous line type: Blank
# parsing line: 1, previous line type: Normal
# creating an object : Inline object
# parsing line: 2, previous line type: Blank
# parsing line: 76, previous line type: Blank
# creating an object : header
# parsing line: 77, previous line type: Blank
# parsing line: 78, previous line type: olLists
# parsing line: 79, previous line type: olLists
# parsing line: 80, previous line type: olLists
# parsing line: 81, previous line type: olLists
# creating an object : ol lists
# creating an object : list item
# parsing line: 0, previous line type: Blank
# parsing line: 1, previous line type: Normal
# parsing line: 2, previous line type: Normal
# parsing line: 3, previous line type: Normal
# parsing line: 81, previous line type: Blank
# parsing line: 82, previous line type: ulLists
# parsing line: 83, previous line type: ulLists
# parsing line: 84, previous line type: ulLists
# creating an object : ul lists
# creating an object : list item
# parsing line: 0, previous line type: Blank
# parsing line: 1, previous line type: Normal
# creating an object : list item
# parsing line: 0, previous line type: Blank
# parsing line: 84, previous line type: Blank
# parsing line: 85, previous line type: olLists
# parsing line: 86, previous line type: olLists
# parsing line: 87, previous line type: olLists
# parsing line: 88, previous line type: olLists
# parsing line: 89, previous line type: olLists
# parsing line: 90, previous line type: olLists
# parsing line: 91, previous line type: olLists
# parsing line: 92, previous line type: olLists
# parsing line: 93, previous line type: olLists
# parsing line: 94, previous line type: olLists
# creating an object : ol lists
# creating an object : list item
# parsing line: 0, previous line type: Blank
# parsing line: 1, previous line type: CodeBlock
# parsing line: 2, previous line type: CodeBlock
# parsing line: 3, previous line type: CodeBlock
# parsing line: 4, previous line type: CodeBlock
# creating an object : code block
# creating an object : list item
# parsing line: 0, previous line type: Blank
# parsing line: 1, previous line type: Normal
# parsing line: 2, previous line type: Blank
# parsing line: 3, previous line type: Blank
# parsing line: 4, previous line type: Normal
# parsing line: 94, previous line type: Blank
# parsing line: 95, previous line type: ulLists
# parsing line: 96, previous line type: ulLists
# parsing line: 97, previous line type: ulLists
# parsing line: 98, previous line type: ulLists
# parsing line: 99, previous line type: ulLists
# parsing line: 100, previous line type: ulLists
# parsing line: 101, previous line type: ulLists
# parsing line: 102, previous line type: ulLists
# parsing line: 103, previous line type: ulLists
# creating an object : ul lists
# creating an object : list item
# parsing line: 0, previous line type: Blank
# parsing line: 1, previous line type: CodeBlock
# creating an object : code block
# creating an object : list item
# parsing line: 0, previous line type: Blank
# parsing line: 1, previous line type: Normal
# parsing line: 2, previous line type: Blank
# parsing line: 3, previous line type: Blank
# parsing line: 4, previous line type: Normal
# parsing line: 5, previous line type: Blank
# creating an object : list item
# parsing line: 0, previous line type: Blank
# creating an object : code block
# parsing line: 103, previous line type: Blank
# creating an object : header
# parsing line: 104, previous line type: Blank
# parsing line: 105, previous line type: Normal
# parsing line: 106, previous line type: Blank
# creating an object : header
# parsing line: 107, previous line type: Blank
# parsing line: 108, previous line type: CodeBlock
# creating an object : code block
# parsing line: 109, previous line type: Blank
# creating an object : header
# parsing line: 110, previous line type: Blank
# parsing line: 111, previous line type: Blank
# parsing line: 112, previous line type: ulLists
# creating an object : ul lists
# creating an object : list item
# parsing line: 0, previous line type: Blank
# creating an object : ul lists
# creating an object : list item
# parsing line: 0, previous line type: Blank
# parsing line: 112, previous line type: Blank
# parsing line: 113, previous line type: Blank
# parsing line: 114, previous line type: ulLists
# creating an object : ul lists
# creating an object : list item
# parsing line: 0, previous line type: Blank
# creating an object : ul lists
# creating an object : list item
# parsing line: 0, previous line type: Blank
# parsing line: 114, previous line type: Blank
# parsing line: 115, previous line type: Blank
# parsing line: 116, previous line type: Blank
# parsing line: 117, previous line type: Blank
# creating an object : header
# parsing line: 118, previous line type: Blank
# parsing line: 119, previous line type: Normal
# creating an object : Inline object
# parsing line: 120, previous line type: Blank
# parsing line: 121, previous line type: Normal
# creating an object : Inline object
# parsing line: 122, previous line type: Blank
# parsing line: 123, previous line type: Normal
# parsing line: 124, previous line type: Blank
# parsing line: 125, previous line type: Blank
# parsing line: 126, previous line type: Blank
# parsing line: 127, previous line type: Blank
# parsing line: 128, previous line type: Blank
# parsing line: 129, previous line type: Normal
# creating an object : Inline object
# parsing line: 130, previous line type: Blank
# parsing line: 131, previous line type: Blank
# parsing line: 132, previous line type: Blank
# parsing line: 133, previous line type: Normal
# parsing line: 134, previous line type: Normal
# creating an object : Inline object
# creating an object : Inline object
# creating an object : Inline object
# parsing line: 135, previous line type: Blank
# parsing line: 136, previous line type: Blank
# parsing line: 137, previous line type: Blank
# parsing line: 138, previous line type: Blank
# parsing line: 139, previous line type: Blank
# creating an object : header
# parsing line: 140, previous line type: Blank
# parsing line: 141, previous line type: Normal
# creating an object : Inline object
# parsing line: 142, previous line type: Blank
# parsing line: 143, previous line type: Normal
# creating an object : Inline object
# parsing line: 144, previous line type: Blank
# parsing line: 145, previous line type: Normal
# creating an object : Inline object
# parsing line: 146, previous line type: Blank
# parsing line: 147, previous line type: Normal
# creating an object : Inline object
# parsing line: 148, previous line type: Blank
# parsing line: 149, previous line type: Normal
# creating an object : Inline object
# parsing line: 150, previous line type: Blank
# parsing line: 151, previous line type: Normal
# creating an object : Inline object
# parsing line: 152, previous line type: Blank
# creating an object : header
# parsing line: 153, previous line type: Blank
# parsing line: 154, previous line type: Normal
# creating an object : Inline object
# parsing line: 155, previous line type: Blank
# parsing line: 156, previous line type: Normal
# creating an object : Inline object
# parsing line: 157, previous line type: Blank
# parsing line: 158, previous line type: Normal
# creating an object : Inline object
# parsing line: 159, previous line type: Blank
# parsing line: 160, previous line type: Normal
# creating an object : Inline object
# parsing line: 161, previous line type: Blank
# parsing line: 162, previous line type: Normal
# creating an object : Inline object
# parsing line: 163, previous line type: Blank
# creating an object : header
# parsing line: 164, previous line type: Blank
# parsing line: 165, previous line type: Normal
# creating an object : Inline object
# parsing line: 166, previous line type: Blank
# parsing line: 167, previous line type: Normal
# creating an object : Inline object
# parsing line: 168, previous line type: Blank
# parsing line: 169, previous line type: Normal
# creating an object : Inline object
# parsing line: 170, previous line type: Blank
# parsing line: 171, previous line type: Blank
# parsing line: 172, previous line type: Blank
# creating an object : header
# parsing line: 173, previous line type: Blank
# parsing line: 174, previous line type: Normal
# parsing line: 175, previous line type: Blank
# parsing line: 176, previous line type: Normal
# parsing line: 177, previous line type: Blank
# parsing line: 178, previous line type: Normal
# parsing line: 179, previous line type: Blank
# parsing line: 180, previous line type: CodeBlock
# parsing line: 181, previous line type: CodeBlock
# parsing line: 182, previous line type: CodeBlock
# parsing line: 183, previous line type: CodeBlock
# creating an object : code block
# parsing line: 184, previous line type: Blank
# creating an object : header
# parsing line: 185, previous line type: Blank
# parsing line: 186, previous line type: Normal
# parsing line: 187, previous line type: Blank
# creating an object : header
# parsing line: 188, previous line type: Blank
# parsing line: 189, previous line type: Blank
# parsing line: 190, previous line type: Table
# parsing line: 191, previous line type: Table
# parsing line: 192, previous line type: Table
# parsing line: 193, previous line type: Table
# creating an object : table
# parsing line: 194, previous line type: Blank
# parsing line: 195, previous line type: Table
# parsing line: 196, previous line type: Table
# parsing line: 197, previous line type: Table
# parsing line: 198, previous line type: Table
# creating an object : table
# parsing line: 199, previous line type: Blank
# parsing line: 200, previous line type: Normal
# parsing line: 201, previous line type: Blank
# parsing line: 202, previous line type: Table
# parsing line: 203, previous line type: Table
# parsing line: 204, previous line type: Table
# creating an object : table
# parsing line: 205, previous line type: Blank
# parsing line: 206, previous line type: Blank
# exporting...
#
# <h1>Test Document</h1>
#
# テスト用のドキュメントです。
#
# <h2>Block elements</h2>
#
# This is
# <em>
# emphasized
# </em>
# .
#
#
# <p> this is *not emphasized*. </p>
#
#
#
# <h2>Automatic escaping for special characters</h2>
#
# &copy;
# AT&T
# 4 < 5
#
# <h2>Inline elements</h2>
#
# In inline elements, <span>
# <em>
# emphasizing
# </em>
#  is enabled.</span>
#
# <h2>Paragraphs and Line Breaks</h2>
#
# This is a first paragraph.
# Rest of first paragraph.
#
# Second Paragraph
#
# <h2>Headers</h2>
#
# <h1>This is an H1.</h1>
#
# <h2>This is an H2.</h2>
#
# <h1>h1</h1>
#
# <h2>h2</h2>
#
# <h3>h3</h3>
#
# <h4>h4</h4>
#
# <h5>h5</h5>
#
# <h3>sharp after the title is ignored</h3>
#
# <h2>Block quote</h2>
#
# <blockquote>
# this is a blockquote.
#
# foo
# bar
#
#
# </blockquote>
#
# <blockquote>
# this is a single
# blockquote paragraph.
#
#
# </blockquote>
#
# <blockquote>
# This is the first level of quoting.
#
# <blockquote>
# Nested level of quoting.
#
#
# </blockquote>
#
# Back to the first level of quoting.
#
#
# </blockquote>
#
# <blockquote>
# <h2>This is a header.</h2>
#
# <ol>
# <li>
# This is the first list item.
# This is the second list item.
#
#
# </li>
#
#
# </ol>
#
# Here's some example code:
#
# <pre><code>
# return shell_exec("echo $input | $markdown_script");
#
#
# </code></pre>
#
#
# </blockquote>
#
# <h2>Lists</h2>
#
# <ul>
# <li>
# item
# item
# item
#
# 1st level
#
#
# </li>
#
# <li>
# <ul>
# <li>
# 2nd level
#
#
# </li>
#
# <li>
# <ul>
# <li>
# 3rd level
#
#
# </li>
#
#
# </ul>
#
#
# </li>
#
# <li>
# 2nd level
#
#
# </li>
#
# <li>
# <ul>
# <li>
# 3rd level
#
#
# </li>
#
#
# </ul>
#
#
# </li>
#
#
# </ul>
#
#
# </li>
#
# <li>
# 1 space
#
#
# </li>
#
# <li>
# <ul>
# <li>
# 2 space
# 3 space
#
# </li>
#
# <li>
# <ul>
# <li>
# 4 space
#
#
# </br>
#
# </li>
#
#
# </ul>
#
#
# </li>
#
#
# </ul>
#
#
# </li>
#
#
# </ul>
#
# <h2>ordered list</h2>
#
# <ol>
# <li>
# item
# item
# item
#
#
# </li>
#
#
# </ol>
#
# <ul>
# <li>
# Indented Paragraph
#
#
# </li>
#
# <li>
#   Ignore spaces before indent.
#
#
# </li>
#
#
# </ul>
#
# <ol>
# <li>
# <pre><code>
# sit amet, consectetuer adipiscing elit. Aliquam hendrerit
# mi posuere lectus.
# Vestibulum enim wisi, viverra nec, fringilla in, laoreet
# vitae, risus. Donec sit amet nisl. Aliquam semper ipsum
# sit amet velit.
#
#
# </code></pre>
#
#
# </li>
#
# <li>
#  This is a list item with two paragraphs. Lorem ipsum dolor
#
#  Suspendisse id sem consectetuer libero luctus adipiscing.
#
#
# </li>
#
#
# </ol>
#
# <ul>
# <li>
# <pre><code>
# > This is a blockquote
# > inside a list item.
#
#
# </code></pre>
#
#
# </li>
#
# <li>
#   A list item with a blockquote:
#
#   A list item with a code block:
#
#
# </li>
#
# <li>
# <pre><code>
# <code goes here>
#
#
# </code></pre>
#
#
# </li>
#
#
# </ul>
#
# <h2>Escaping listing</h2>
#
# 1986\. What a great season.
#
# <h2>Automatically convert escape codes in code block.</h2>
#
# <pre><code>
# <div> &
#
#
# </code></pre>
#
# <h3>Horizontal rules</h3>
#
# <hr>
#
#
#
# <ul>
# <li>
# <ul>
# <li>
# *
#
#
# </li>
#
#
# </ul>
#
#
# </li>
#
#
# </ul>
#
# <hr>
#
#
#
# <ul>
# <li>
# <ul>
# <li>
# -
#
#
# </li>
#
#
# </ul>
#
#
# </li>
#
#
# </ul>
#
# <hr>
#
#
#
# <hr>
#
#
#
# <h2>Links</h2>
#
# This is
# <a></a>
#
#  inline link.
#
# This is
# <a></a>
#
#  reference-style link.
#
# This is [an example] [id] reference-style link.
#
# <a href="http://google.com/">Google</a>
#
#
# I get 10 times more traffic from
# <a href="http://google.com/">Google</a>
#
#  than from
# <a href="http://search.yahoo.com/">Yahoo</a>
#
#  or
# <a href="http://search.msn.com/">MSN</a>
#
# .
#
# <h2>Emphasis</h2>
#
# <em>
# single asterisks
# </em>
#  -> <em>single asterisks</em>
#
# <em>
# single underscores
# </em>
#  -> <em>single underscores</em>
#
# <b>
# double asterisks
# </b>
#  -> <strong>double asterisks</strong>
#
# <b>
# double underscores
# </b>
#  -> <strong>double underscores</strong>
#
# un
# <em>
# fucking
# </em>
# believable -> un<em>fucking</em>believable
#
# You're f\
# <em>
# \
# </em>
# king crazy.
#
# <h2>Inline code block</h2>
#
# Use the
# <code>
# printf()
# </code>
#  function.
#
# <code>
# files = `ls`.split
# </code>
#
# <code>
# `ps`
# </code>
#
# <code>
# ``double-back-quote``
# </code>
#
# Please don't use any
# <code>
# <blink>
# </code>
#  tags.
#
# <h2>Images</h2>
#
# <img src="URL">
#
# <img src="URL "タイトル"">
#
# <img>
#
# <h1>Automatic Link</h1>
#
# <http://example.com/>
#
# <address@example.com>
#
# converted into:
#
# <pre><code>
# <a href="&#x6D;&#x61;i&#x6C;&#x74;&#x6F;:&#x61;&#x64;&#x64;&#x72;&#x65;
# &#115;&#115;&#64;&#101;&#120;&#x61;&#109;&#x70;&#x6C;e&#x2E;&#99;&#111;
# &#109;">&#x61;&#x64;&#x64;&#x72;&#x65;&#115;&#115;&#64;&#101;&#120;&#x61;
# &#109;&#x70;&#x6C;e&#x2E;&#99;&#111;&#109;</a>
#
#
# </code></pre>
#
# <h1>Backslash Escapes</h1>
#
# \\ \` \* \_ \{ \} \[ \] \( \) \# \+ \- \. \!
#
# <h1>Tables</h1>
#
# <table>
# <tr>
# <th>  TH  </th>
# <th>  TH  </th>
#
# </tr>
# <tr>
# <td>  TH  </td>
# <td>  TH  </td>
# </tr>
# <tr>
# <td>  TH  </td>
# <td>  TH  </td>
# </tr>
# <tr>
# </tr>
#
# </table>
# <table>
# <tr>
# <th>  TH  </th>
# <th>  TH  </th>
#
# </tr>
# <tr>
# <td>  TH  </td>
# <td>  TH  </td>
# </tr>
# <tr>
# <td>  TH  </td>
# <td>  TH  </td>
# </tr>
# <tr>
# <td>  TH  </td>
# </tr>
#
# </table>
# alignment
#
# <table>
# <tr>
# <th> left </th>
# <th> center </th>
# <th> right</th>
#
# </tr>
# <tr>
# <td align="left"> right</td>
# <td align="center"> right</td>
# <td align="right"> right</td>
# </tr>
# <tr>
# <td align="left"> right</td>
# </tr>
#
# </table>
